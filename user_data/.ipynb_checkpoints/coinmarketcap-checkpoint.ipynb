# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from data_provider.coinmarketcap import CoinMarketCapAPI, CoinMarketCapAPIError
import pandas as pd
from datetime import datetime
from datetime import timezone
# Out:
# <style>.container { width:100% !important; }</style>

# %%
SANDBOX_API_KEY = 'ecef1c0b-5806-45ba-9d4e-9cb94a5e67b4'
cmc = CoinMarketCapAPI(SANDBOX_API_KEY)

# %%
cryptocurrency_listings_latest = cmc.cryptocurrency_listings_latest(limit=200).data
cryptocurrency_listings_df = pd.DataFrame(cryptocurrency_listings_latest)
cryptocurrency_listings_df['request_time'] = datetime.now()
cryptocurrency_listings_df = cryptocurrency_listings_df.sort_values('cmc_rank').set_index('id')
cryptocurrency_listings_df['is_stable_coin'] = cryptocurrency_listings_df['tags'].apply(lambda x: 'stablecoin' in x )
cryptocurrency_listings_df.loc[:, 'is_meme'] = cryptocurrency_listings_df['tags'].apply(lambda x: 'memes' in x )
cryptocurrency_listings_df['datetime_issue'] = cryptocurrency_listings_df['date_added'].apply(lambda x: datetime.fromisoformat(x[:-1]))

# %%
cmc_id_mapping = cryptocurrency_listings_df['symbol'].to_dict()
cmc_id_mapping = {v: k for k, v in cmc_id_mapping.items()}

# %%
shit_coin_info_df = cryptocurrency_listings_df[~cryptocurrency_listings_df['is_stable_coin']].copy()

# %%
shit_coin_info_df[shit_coin_info_df['is_meme']]
# Out:
#               name symbol       slug  num_market_pairs  \
# id
# 74        Dogecoin   DOGE   dogecoin               466
# 5994     Shiba Inu   SHIB  shiba-inu               337
# 9436  Dogelon Mars   ELON    dogelon                43
#
#                     date_added  \
# id
# 74    2013-12-15T00:00:00.000Z
# 5994  2020-08-01T00:00:00.000Z
# 9436  2021-04-23T00:00:00.000Z
#
#                                                    tags    max_supply  \
# id
# 74    [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 5994      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 9436  [memes, payments, polygon-ecosystem, doggone-d...  1.000000e+15
#
#       circulating_supply  total_supply  \
# id
# 74          1.326708e+11  1.326708e+11
# 5994        5.490633e+14  5.897350e+14
# 9436        5.536020e+14  1.000000e+15
#
#                                                platform  cmc_rank  \
# id
# 74                                                 None        13
# ...

# %%
dino_coins = ['ETC', 'ZEC', 'LTC', 'NEO', 'BCH', 'XRP', 'OMG', 'EOS', 'DASH']
dino_coins_cmc = [cmc_id_mapping[d] for d in dino_coins]

# %%
shit_coin_info_df.loc[dino_coins_cmc]
# Out:
#                   name symbol              slug  num_market_pairs  \
# id
# 1321  Ethereum Classic    ETC  ethereum-classic               296
# 1437             Zcash    ZEC             zcash               249
# 2             Litecoin    LTC          litecoin               765
# 1376               Neo    NEO               neo               245
# 1831      Bitcoin Cash    BCH      bitcoin-cash               589
# 52                 XRP    XRP               xrp               712
# 1808       OMG Network    OMG               omg               283
# 1765               EOS    EOS               eos               434
# 131               Dash   DASH              dash               335
#
#                     date_added  \
# id
# 1321  2016-07-24T00:00:00.000Z
# 1437  2016-10-29T00:00:00.000Z
# 2     2013-04-28T00:00:00.000Z
# 1376  2016-09-08T00:00:00.000Z
# 1831  2017-07-23T00:00:00.000Z
# 52    2013-08-04T00:00:00.000Z
# 1808  2017-07-14T00:00:00.000Z
# 1765  2017-07-01T00:00:00.000Z
# ...

# %% [markdown]
# ltc. 11/8 7:00 - 11/10 3:00
# etc  11/8  15:00 - 11/10 3:00
# bch. 11/7 19:00 - 11/10 7:00

# %%
shit_coin_info_df.loc[shit_coin_info_df['datetime_issue']<=datetime(2017, 12, 31)].head(20)
# Out:
#                   name symbol              slug  num_market_pairs  \
# id
# 1              Bitcoin    BTC           bitcoin              9357
# 1027          Ethereum    ETH          ethereum              5659
# 1839               BNB    BNB               bnb               813
# 52                 XRP    XRP               xrp               712
# 2010           Cardano    ADA           cardano               426
# 74            Dogecoin   DOGE          dogecoin               466
# 2             Litecoin    LTC          litecoin               765
# 1958              TRON    TRX              tron               593
# 1975         Chainlink   LINK         chainlink               633
# 1831      Bitcoin Cash    BCH      bitcoin-cash               589
# 328             Monero    XMR            monero               174
# 512            Stellar    XLM           stellar               420
# 1321  Ethereum Classic    ETC  ethereum-classic               296
# ...

# %%
cryptocurrency_listings_df.loc[7129, 'tags']
# Out:
# ['cosmos-ecosystem',
#  'stablecoin',
#  'terra-ecosystem',
#  'injective-ecosystem',
#  'bnb-chain',
#  'usd-stablecoin']

# %%
cryptocurrency_trending_latest = cmc.cryptocurrency_listings_latest()

# %%
shit_coin_info_df.loc[cmc_id_mapping['XRP']]['tags']
# Out:
# ['medium-of-exchange',
#  'enterprise-solutions',
#  'binance-chain',
#  'arrington-xrp-capital-portfolio',
#  'galaxy-digital-portfolio',
#  'a16z-portfolio',
#  'pantera-capital-portfolio']
